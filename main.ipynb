# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Ritesh Kandwal\Documents\4 STUDY\PYTHON\projects\movierecommend

# %%
movies = pd.read_csv('tmdb_5000_movies/tmdb_5000_movies.csv.csv')
credits = pd.read_csv('tmdb_5000_credits/tmdb_5000_credits.csv')

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Ritesh Kandwal\Documents\4 STUDY\PYTHON\projects\movierecommend
# ['.ipynb_checkpoints', 'main.ipynb', 'tmdb_5000_credits', 'tmdb_5000_movies', 'Untitled.ipynb']

# %%
import os
print(os.listdir('tmdb_5000_movies'))
# Out:
# ['tmdb_5000_movies.csv.csv']

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
credits.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movies=movies.merge(credits, on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %%
print(set(movies.columns))
# Out:
# {'vote_average', 'homepage', 'status', 'movie_id', 'genres', 'tagline', 'original_title', 'release_date', 'popularity', 'id', 'cast', 'runtime', 'production_countries', 'budget', 'production_companies', 'title', 'crew', 'original_language', 'revenue', 'spoken_languages', 'overview', 'keywords', 'vote_count'}

# %%
movies.rename(columns={'movie_id_y':'movie_id', 'crew_y':'crew', 'cast_y':'cast'},inplace=True)

# %%
movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
import ast

# %%
def convert(text):
    l=[]
    for i in ast.literal_eval(text):
        l.append(i['name'])
    return l

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies['genres']= movies['genres'].apply(convert)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords']=movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
def convert2(text):
    l=[]
    for i in text[:3]:
            l.append(i)
    return l

# %%
movies['cast']=movies['cast'].apply(convert2)

# %%
movies['cast'][1]
# Out:
# ['[', '{', '"']

# %%
def fetch_director(text):
    l=[]
    for i in ast.literal_eval(text):
        if i['job']=='Director':
            l.append(i['name'])
    return l

# %%
movies['crew']=movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id            title  \
# 637      82695   Les Misérables
# 3054     37931        MacGruber
# 2461     74643       The Artist
# 1963      4233         Scream 2
# 377       4477  The Devil's Own
#
#                                                overview  \
# 637   An adaptation of the successful stage musical ...
# 3054  Ex-special operative MacGruber (Forte) is call...
# 2461  Hollywood, 1927: As silent movie star George V...
# 1963  Two years after the terrifying events that occ...
# 377   Frankie McGuire, one of the IRA's deadliest as...
#
#                            genres  \
# 637       [Drama, Music, Romance]
# 3054  [Action, Adventure, Comedy]
# 2461     [Drama, Comedy, Romance]
# 1963            [Horror, Mystery]
# 377      [Crime, Thriller, Drama]
#
#                                                keywords       cast  \
# 637   [france, robbery, brothel, mayor, star, musica...  [[, {, "]
# 3054        [aftercreditsstinger, duringcreditsstinger]  [[, {, "]
# ...

# %%
def space_remover(text):
    l=[]
    for i in text:
        l.append(i.replace(" ",""))
    return l

# %%
movies['cast'] = movies['cast'].apply(space_remover)
movies['crew'] = movies['crew'].apply(space_remover)
movies['genres'] = movies['genres'].apply(space_remover)
movies['keywords'] = movies['keywords'].apply(space_remover)

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new =movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags']=new['tags'].apply(lambda x:" ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
